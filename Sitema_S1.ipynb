# %% [markdown]
# <a href="https://colab.research.google.com/github/luzydata/dataton-2022/blob/develop-gaby/Sitema_S1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set  de datos del sistema S1

# %%
import pandas as pd
import numpy as np
import json 
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
        #path1:path of the generated zip file  #path2:path of the output directory
# !unzip "/content/drive/MyDrive/Dataton_2022/data/S3/s3s.zip" -d "/content/drive/MyDrive/Dataton_2022/data/S3"

# %%
datos_mx = pd.read_csv('/content/drive/MyDrive/Dataton_2022/data/areas_geoestadisticas_estatales_municipales_y_localidades_2020.csv')

# %%
datos_mx.head()
# Out:
#        MAPA  CVE_ENT         NOM_ENT NOM_ABR  CVE_MUN         NOM_MUN  \
# 0  10010001        1  Aguascalientes    Ags.        1  Aguascalientes
# 1  10010094        1  Aguascalientes    Ags.        1  Aguascalientes
# 2  10010096        1  Aguascalientes    Ags.        1  Aguascalientes
# 3  10010100        1  Aguascalientes    Ags.        1  Aguascalientes
# 4  10010102        1  Aguascalientes    Ags.        1  Aguascalientes
#
#    CVE_LOC                 NOM_LOC AMBITO         LATITUD         LONGITUD  \
# 0        1          Aguascalientes      U  21°52´47.362"N  102°17´45.768"W
# 1       94          Granja Adelita      R  21°52´18.749"N  102°22´24.710"W
# 2       96               Agua Azul      R  21°53´01.522"N  102°21´25.639"W
# 3      100           Rancho Alegre      R  21°51´16.556"N  102°22´21.884"W
# 4      102  Los Arbolitos [Rancho]      R  21°46´48.650"N  102°21´26.261"W
#
#    LAT_DECIMAL  LON_DECIMAL  ALTITUD CVE_CARTA POB_TOTAL POB_MASCULINA  \
# ...

# %%
datos_mx.shape
# Out:
# (300178, 19)

# %% [markdown]
# Leyendo los archivos json

# %%
# Cambios
def read_all_json(folder_path, state_name):
    df = pd.DataFrame()
    for file in os.listdir(folder_path):
        file_path = f"{folder_path}/{file}"
        f = open(file_path, encoding="utf8")
        data = json.load(f)
        df_1 = pd.json_normalize(data, max_level=5)
        
        df_1['estado'] = state_name
        df = pd.concat([df, df_1])
    return df

# %% [markdown]
# Chiapas y Estado de México

# %%
chiapas = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/Chiapas', 'CHIAPAS')

# %%
edomex = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/EDOMEX', 'EDOMEX')

# %%
i = 10
chiapas.columns[i], chiapas[chiapas.columns[i]].iloc[0]
# Out:
# ('declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad',
#  [{'tipoOperacion': 'AGREGAR',
#    'nivel': {'clave': 'PRI', 'valor': 'PRIMARIA'},
#    'institucionEducativa': {'nombre': 'ESCUELA BENITO JUAREZ',
#     'ubicacion': 'MX'},
#    'carreraAreaConocimiento': '',
#    'estatus': 'FINALIZADO',
#    'documentoObtenido': 'CERTIFICADO',
#    'fechaObtencion': '1992-12-07'},
#   {'tipoOperacion': 'AGREGAR',
#    'nivel': {'clave': 'PRI', 'valor': 'PRIMARIA'},
#    'institucionEducativa': {'nombre': 'ESCUELA BENITO JUAREZ',
#     'ubicacion': 'MX'},
#    'carreraAreaConocimiento': '',
#    'estatus': 'FINALIZADO',
#    'documentoObtenido': 'CERTIFICADO',
#    'fechaObtencion': '1992-12-07'}])

# %%
#antes 5
chiapas.shape, edomex.shape
# Out:
# ((33743, 116), (56181, 135))

# %%
bcs = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/BajaCaliforniaSur', 'BAJA CALIFORNIA SUR')

# %%
chihuahua = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/Chihuahua', 'CHIHUAHUA')

# %%
guanajuato = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/GUANAJUATO', 'GUANAJUATO')

# %%
INAI = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/INAI', 'INAI')

# %%
INE = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/INE', 'INE')

# %%
puebla = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/Puebla', 'PUEBLA')

# %%
quintana_roo = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/QUINTANAROO', 'QUINTANA ROO')

# %%
san_luis_potosi = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/SANLUISPOTOSI', 'SAN LUIS POTOSI')

# %%
aguascalientes = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/SESEA_AGUASCALIENTES', 'AGUASCALIENTES')

# %%
jalisco = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/SESEA_JALISCO', 'JALISCO')

# %%
tabasco = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/TABASCO', 'TABASCO')

# %%
tlaxaca = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/TLAXCALA', 'TLAXCALA')

# %%
zacatecas = read_all_json('/content/drive/MyDrive/Dataton_2022/data/S1/ZACATECAS', 'ZACATECAS')

# %% [markdown]
# Guardando archivos csv

# %%
bcs.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/bcs.csv', encoding='utf-8', index=False)

# %%
chiapas.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/chiapas.csv', encoding='utf-8', index=False)

# %%
chihuahua.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/chihuahua.csv', encoding='utf-8', index=False)

# %%
edomex.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/edomex.csv', encoding='utf-8', index=False)

# %%
guanajuato.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/guanajuato.csv', encoding='utf-8', index=False)

# %%
INAI.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/INAI.csv', encoding='utf-8', index=False)

# %%
INE.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/INE.csv', encoding='utf-8', index=False)

# %%
puebla.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/puebla.csv', encoding='utf-8', index=False)

# %%
quintana_roo.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/quintana_roo.csv', encoding='utf-8', index=False)

# %%
san_luis_potosi.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/san_luis_potosi.csv', encoding='utf-8', index=False)

# %%
aguascalientes.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/aguascalientes.csv', encoding='utf-8', index=False)

# %%
jalisco.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/jalisco.csv', encoding='utf-8', index=False)

# %%
tabasco.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/tabasco.csv', encoding='utf-8', index=False)

# %%
tlaxaca.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/tlaxaca.csv', encoding='utf-8', index=False)

# %%
zacatecas.to_csv('/content/drive/MyDrive/Dataton_2022/data/csv/zacatecas.csv', encoding='utf-8', index=False)

# %%
chiapas.columns[0:50]
# Out:
# Index(['id', 'metadata.actualizacion', 'metadata.institucion', 'metadata.tipo',
#        'metadata.declaracionCompleta',
#        'metadata.actualizacionConflictoInteres',
#        'declaracion.situacionPatrimonial.datosGenerales.nombre',
#        'declaracion.situacionPatrimonial.datosGenerales.primerApellido',
#        'declaracion.situacionPatrimonial.datosGenerales.segundoApellido',
#        'declaracion.situacionPatrimonial.datosGenerales.correoElectronico.institucional',
#        'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.tipoOperacion',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion',
# ...

# %%
indices_col = [3, 4, 9, 11, 21, 22, 23, 24, 25, 31, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 100, 101, 102, 103, 104, 105]
conservar_col = []
arr_chiapas = np.array(chiapas.columns)
for i in range(len(arr_chiapas)):
  if i not in indices_col:
    conservar_col.append(arr_chiapas[i])

conservar_col, len(conservar_col)
# Out:
# (['id',
#   'metadata.actualizacion',
#   'metadata.institucion',
#   'metadata.actualizacionConflictoInteres',
#   'declaracion.situacionPatrimonial.datosGenerales.nombre',
#   'declaracion.situacionPatrimonial.datosGenerales.primerApellido',
#   'declaracion.situacionPatrimonial.datosGenerales.segundoApellido',
#   'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.empleoCargoComision',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.contratadoPorHonorarios',
#   'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision',
# ...

# %%
chiapas_2 = chiapas[conservar_col]

# %%
chiapas_2.head()
# Out:
#                                      id metadata.actualizacion  \
# 0  72f593d6-e640-44d8-b7db-87169de91a50   2021-11-29T20:19:37Z
# 1  abee093a-0ac5-490b-a1d6-952ca7c4fb58   2021-11-29T20:20:45Z
# 2  6d806e2a-44d5-4012-9fd3-ea2a3ca7713a   2021-11-29T20:21:56Z
# 3  58dd3f17-00df-43ce-859c-d5b6f4179d18   2021-12-03T21:04:49Z
# 4  a698571c-5832-4e43-ad1e-69006aec825b   2021-12-06T15:16:13Z
#
#                                 metadata.institucion  \
# 0  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 1  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 2  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 3  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO, ...
# 4  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
#
#    metadata.actualizacionConflictoInteres  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
# ...

# %%
edomex_2 = edomex[conservar_col]
edomex_2.shape, edomex_2.columns
# Out:
# ((56181, 80), Index(['id', 'metadata.actualizacion', 'metadata.institucion',
#         'metadata.actualizacionConflictoInteres',
#         'declaracion.situacionPatrimonial.datosGenerales.nombre',
#         'declaracion.situacionPatrimonial.datosGenerales.primerApellido',
#         'declaracion.situacionPatrimonial.datosGenerales.segundoApellido',
#         'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.empleoCargoComision',
#         'declaracion.situacionPatrimonial.datosEmpleoCargoComision.contratadoPorHonorarios',
# ...

# %% [markdown]
# # Nombres

# %%
def names_std(df):
  df = df.replace('Í','I', regex=True)
  df = df.replace('Ó','O', regex=True)
  df = df.replace('Á','A', regex=True)
  df = df.replace('É','E', regex=True)
  df = df.replace('Ú','U', regex=True)
  df = df.replace('í','i', regex=True)
  df = df.replace('ó','o', regex=True)
  df = df.replace('á','a', regex=True)
  df = df.replace('é','e', regex=True)
  df = df.replace('ú','u', regex=True)
  df = df.replace('ñ','n', regex=True)
  df = df.replace('Ñ','N', regex=True)

  df['servidorPublicoSancionado.nombreCompleto'] = df['declaracion.situacionPatrimonial.datosGenerales.nombre'] + ' ' + df['declaracion.situacionPatrimonial.datosGenerales.primerApellido'] + ' ' + df['declaracion.situacionPatrimonial.datosGenerales.segundoApellido']
  df = df.drop(['declaracion.situacionPatrimonial.datosGenerales.nombre', 'declaracion.situacionPatrimonial.datosGenerales.primerApellido', 'declaracion.situacionPatrimonial.datosGenerales.segundoApellido'], axis=1)
  
  return df

# %%
chiapas_s1 = names_std(chiapas_2)

# %%
chiapas_s1.head()
# Out:
#                                      id metadata.actualizacion  \
# 0  72f593d6-e640-44d8-b7db-87169de91a50   2021-11-29T20:19:37Z
# 1  abee093a-0ac5-490b-a1d6-952ca7c4fb58   2021-11-29T20:20:45Z
# 2  6d806e2a-44d5-4012-9fd3-ea2a3ca7713a   2021-11-29T20:21:56Z
# 3  58dd3f17-00df-43ce-859c-d5b6f4179d18   2021-12-03T21:04:49Z
# 4  a698571c-5832-4e43-ad1e-69006aec825b   2021-12-06T15:16:13Z
#
#                                 metadata.institucion  \
# 0  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 1  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 2  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 3  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO, ...
# 4  HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
#
#    metadata.actualizacionConflictoInteres  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
# ...

# %%
edomex_s1 = names_std(edomex_2)

# %%
edomex_s1.head()
# Out:
#                          id metadata.actualizacion  \
# 0  6253a26f201c78ff11e318ab   2021-05-03T15:40:00Z
# 1  6253a26f201c78ff11e318b0   2021-05-03T15:42:34Z
# 2  6253a270201c78ff11e318b5   2021-05-03T15:44:25Z
# 3  6253a270201c78ff11e318b8   2021-05-03T15:45:59Z
# 4  6253a270201c78ff11e318bd   2021-05-03T15:49:32Z
#
#                         metadata.institucion  \
# 0  Universidad Autonoma del Estado de Mexico
# 1  Universidad Autonoma del Estado de Mexico
# 2  Universidad Autonoma del Estado de Mexico
# 3  Universidad Autonoma del Estado de Mexico
# 4  Universidad Autonoma del Estado de Mexico
#
#    metadata.actualizacionConflictoInteres  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   declaracion.situacionPatrimonial.datosGenerales.nombre  \
# 0                                     MARTIN PANFILO
# ...

# %%
chiapas_s1.columns
# Out:
# Index(['id', 'metadata.actualizacion', 'metadata.institucion',
#        'metadata.actualizacionConflictoInteres',
#        'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.empleoCargoComision',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.contratadoPorHonorarios',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision',
#        'declaracion.situacionPatrimonial.datosEmpleoCargoComision.funcionPrincipal',
# ...

# %%
chiapas_s1.rename({'metadata.actualizacion':'Fecha_actualizacion', 'metadata.institucion':'Institucion',
       'metadata.actualizacionConflictoInteres':'Actualizacion_Conflicto_Interes',
       'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad':'Escolaridad',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno':'Nivel_Orden_Gobierno',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico':'Ambito_Publico',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico':'Nombre_Ente_Publico',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion':'Area_Adscripcion',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.empleoCargoComision':'Empleo_Cargo_Comision',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.contratadoPorHonorarios':'Contratado_Por_Honorarios',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision':'Nivel_Empleo_Cargo_Comision',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.funcionPrincipal':'Funcion_Principal',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.fechaTomaPosesion':'Fecha_Toma_Posesion',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.coloniaLocalidad':'Localidad',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.municipioAlcaldia.clave':'Clave_Alcaldia',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.municipioAlcaldia.valor':'Nombre_Alcaldia',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.entidadFederativa.clave':'Clave_Entidad_Federativa',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.entidadFederativa.valor':'Nombre_Entidad_Federativa',
       'declaracion.situacionPatrimonial.experienciaLaboral.ninguno':'Experiencia_Laboral',
       'declaracion.situacionPatrimonial.experienciaLaboral.experiencia':'Experiencia_Laboral_SI',
       'declaracion.situacionPatrimonial.ingresos.remuneracionMensualCargoPublico.valor':'Remuneracion_Mensual_Cargo_Publico_Valor',
       'declaracion.situacionPatrimonial.ingresos.remuneracionMensualCargoPublico.moneda':'Remuneracion_Mensual_Cargo_Publico_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosMensualesTotal.valor':'Otros_Ingresos_Mensuales_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosMensualesTotal.moneda':'Otros_Ingresos_Mensuales_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.remuneracionTotal.valor':'Actividad_Industrial_Comercial_Empresarial_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.remuneracionTotal.moneda':'Actividad_Industrial_Comercial_Empresarial_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.actividades':'Actividad_Industrial_Comercial_Empresarial',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.remuneracionTotal.valor':'Actividad_Financiera_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.remuneracionTotal.moneda':'Actividad_Financiera_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.actividades':'Actividad_Financiera',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.remuneracionTotal.valor':'Servicios_Profesionales_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.remuneracionTotal.moneda':'Servicios_Profesionales_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.servicios':'ServiciosProfesionales',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.remuneracionTotal.valor':'Enajenacion_Bienes_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.remuneracionTotal.moneda':'Enajenacion_Bienes_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.bienes':'Enajenacion_Bienes',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.remuneracionTotal.valor':'Otros_Ingresos_Remuneracion_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.remuneracionTotal.moneda':'Otros_Ingresos_Remuneracion_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.ingresos':'Otros_Ingresos',
       'declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.valor':'Ingreso_Mensual_Neto_Declarante_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.moneda':'Ingreso_Mensual_Neto_Declarante_Moneda',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosMensualesNetos.valor':'Total_Ingresos_Mensuales_Netos_Valor',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosMensualesNetos.moneda':'Total_Ingresos_Mensuales_Netos_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.servidorPublicoAnioAnterior':'Servidor_Publico_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.remuneracionNetaCargoPublico.valor':'Remuneracion_Neta_Cargo_Publico_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.remuneracionNetaCargoPublico.moneda':'Remuneracion_Neta_Cargo_Publico_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresosTotal.valor':'Otros_Ingresos_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresosTotal.moneda':'Otros_Ingresos_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.remuneracionTotal.valor':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.remuneracionTotal.moneda':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.actividades':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.remuneracionTotal.valor':'Actividad_Financiera_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.remuneracionTotal.moneda':'Actividad_Financiera_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.actividades':'Actividad_Financiera_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.remuneracionTotal.valor':'Servicios_Profesionales_Remuneracion_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.remuneracionTotal.moneda':'Servicios_Profesionales_Remuneracion_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.servicios':'Servicios_Profesionales_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.remuneracionTotal.valor':'Otros_Ingresos_Remuneracion_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.remuneracionTotal.moneda':'Otros_Ingresos_Remuneracion_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.ingresos':'Otros_Ingresos_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.ingresoNetoAnualDeclarante.valor':'Ingreso_Neto_Anual_Declarante_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.ingresoNetoAnualDeclarante.moneda':'Ingreso_Neto_Anual_Declarante_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.totalIngresosNetosAnuales.valor':'Total_Ingresos_Netos_Anuales_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.totalIngresosNetosAnuales.moneda':'Total_Ingresos_Netos_Anuales_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.fechaIngreso':'Fecha_Ingreso_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.fechaConclusion':'Fecha_Ingreso_Anio_Anterior',
       'estado':'Estado',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.cuentaConOtroCargoPublico':'Cuenta_Con_Otro_Cargo_Publico',
       'declaracion.situacionPatrimonial.ingresos.remuneracionAnualCargoPublico.valor':'Ingresos_Remuneracion_Anual_Cargo_Publico_Valor',
       'declaracion.situacionPatrimonial.ingresos.remuneracionAnualCargoPublico.moneda':'Ingresos_Remuneracion_Anual_Cargo_Publico_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosAnualesTotal.valor':'Otros_Ingresos_Anuales_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosAnualesTotal.moneda':'Otros_Ingresos_Anuales_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoAnualNetoDeclarante.valor':'Ingreso_Anual_Neto_Declarante_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoAnualNetoDeclarante.moneda':'Ingreso_Anual_Neto_Declarante_Moneda',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosAnualesNetos.valor':'Total_Ingresos_Anuales_Netos_Valor',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosAnualesNetos.moneda':'Total_Ingresos_Anuales_Netos_Moneda',
       'servidorPublicoSancionado.nombreCompleto':'Nombre_Completo'}, axis=1)
# Out:
#                                        id   Fecha_actualizacion  \
# 0    72f593d6-e640-44d8-b7db-87169de91a50  2021-11-29T20:19:37Z
# 1    abee093a-0ac5-490b-a1d6-952ca7c4fb58  2021-11-29T20:20:45Z
# 2    6d806e2a-44d5-4012-9fd3-ea2a3ca7713a  2021-11-29T20:21:56Z
# 3    58dd3f17-00df-43ce-859c-d5b6f4179d18  2021-12-03T21:04:49Z
# 4    a698571c-5832-4e43-ad1e-69006aec825b  2021-12-06T15:16:13Z
# ..                                    ...                   ...
# 195  b689b288-c96f-43b2-ade8-c065e339f2df  2021-12-15T15:54:54Z
# 196  1465ddce-2da8-43dd-a142-b85d07491682  2022-03-01T19:27:29Z
# 197  c2573dbc-5552-4c48-8a56-da6702b0c7e3  2021-05-31T22:59:43Z
# 198  fcd54627-5cfa-460b-be3d-b01462e8b639  2021-07-01T00:09:04Z
# 199  0b8d6875-d7f1-4be3-b4d0-c16fcfccdd24  2021-09-02T17:46:36Z
#
#                                            Institucion  \
# 0    HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# 1    HONORABLE AYUNTAMIENTO MUNICIPAL DE OCOSINGO C...
# ...

# %%
edomex_s1.rename({'metadata.actualizacion':'Fecha_actualizacion', 'metadata.institucion':'Institucion',
       'metadata.actualizacionConflictoInteres':'Actualizacion_Conflicto_Interes',
       'declaracion.situacionPatrimonial.datosCurricularesDeclarante.escolaridad':'Escolaridad',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelOrdenGobierno':'Nivel_Orden_Gobierno',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.ambitoPublico':'Ambito_Publico',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nombreEntePublico':'Nombre_Ente_Publico',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.areaAdscripcion':'Area_Adscripcion',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.empleoCargoComision':'Empleo_Cargo_Comision',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.contratadoPorHonorarios':'Contratado_Por_Honorarios',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.nivelEmpleoCargoComision':'Nivel_Empleo_Cargo_Comision',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.funcionPrincipal':'Funcion_Principal',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.fechaTomaPosesion':'Fecha_Toma_Posesion',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.coloniaLocalidad':'Localidad',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.municipioAlcaldia.clave':'Clave_Alcaldia',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.municipioAlcaldia.valor':'Nombre_Alcaldia',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.entidadFederativa.clave':'Clave_Entidad_Federativa',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.domicilioMexico.entidadFederativa.valor':'Nombre_Entidad_Federativa',
       'declaracion.situacionPatrimonial.experienciaLaboral.ninguno':'Experiencia_Laboral',
       'declaracion.situacionPatrimonial.experienciaLaboral.experiencia':'Experiencia_Laboral_SI',
       'declaracion.situacionPatrimonial.ingresos.remuneracionMensualCargoPublico.valor':'Remuneracion_Mensual_Cargo_Publico_Valor',
       'declaracion.situacionPatrimonial.ingresos.remuneracionMensualCargoPublico.moneda':'Remuneracion_Mensual_Cargo_Publico_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosMensualesTotal.valor':'Otros_Ingresos_Mensuales_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosMensualesTotal.moneda':'Otros_Ingresos_Mensuales_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.remuneracionTotal.valor':'Actividad_Industrial_Comercial_Empresarial_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.remuneracionTotal.moneda':'Actividad_Industrial_Comercial_Empresarial_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadIndustrialComercialEmpresarial.actividades':'Actividad_Industrial_Comercial_Empresarial',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.remuneracionTotal.valor':'Actividad_Financiera_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.remuneracionTotal.moneda':'Actividad_Financiera_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.actividadFinanciera.actividades':'Actividad_Financiera',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.remuneracionTotal.valor':'Servicios_Profesionales_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.remuneracionTotal.moneda':'Servicios_Profesionales_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.serviciosProfesionales.servicios':'ServiciosProfesionales',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.remuneracionTotal.valor':'Enajenacion_Bienes_Remuneracion_Valor',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.remuneracionTotal.moneda':'Enajenacion_Bienes_Remuneracion_Moneda',
       'declaracion.situacionPatrimonial.ingresos.enajenacionBienes.bienes':'Enajenacion_Bienes',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.remuneracionTotal.valor':'Otros_Ingresos_Remuneracion_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.remuneracionTotal.moneda':'Otros_Ingresos_Remuneracion_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresos.ingresos':'Otros_Ingresos',
       'declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.valor':'Ingreso_Mensual_Neto_Declarante_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoMensualNetoDeclarante.moneda':'Ingreso_Mensual_Neto_Declarante_Moneda',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosMensualesNetos.valor':'Total_Ingresos_Mensuales_Netos_Valor',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosMensualesNetos.moneda':'Total_Ingresos_Mensuales_Netos_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.servidorPublicoAnioAnterior':'Servidor_Publico_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.remuneracionNetaCargoPublico.valor':'Remuneracion_Neta_Cargo_Publico_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.remuneracionNetaCargoPublico.moneda':'Remuneracion_Neta_Cargo_Publico_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresosTotal.valor':'Otros_Ingresos_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresosTotal.moneda':'Otros_Ingresos_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.remuneracionTotal.valor':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.remuneracionTotal.moneda':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadIndustrialComercialEmpresarial.actividades':'Actividad_Industrial_Comercial_Empresarial_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.remuneracionTotal.valor':'Actividad_Financiera_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.remuneracionTotal.moneda':'Actividad_Financiera_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.actividadFinanciera.actividades':'Actividad_Financiera_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.remuneracionTotal.valor':'Servicios_Profesionales_Remuneracion_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.remuneracionTotal.moneda':'Servicios_Profesionales_Remuneracion_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.serviciosProfesionales.servicios':'Servicios_Profesionales_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.remuneracionTotal.valor':'Otros_Ingresos_Remuneracion_Total_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.remuneracionTotal.moneda':'Otros_Ingresos_Remuneracion_Total_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.otrosIngresos.ingresos':'Otros_Ingresos_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.ingresoNetoAnualDeclarante.valor':'Ingreso_Neto_Anual_Declarante_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.ingresoNetoAnualDeclarante.moneda':'Ingreso_Neto_Anual_Declarante_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.totalIngresosNetosAnuales.valor':'Total_Ingresos_Netos_Anuales_Anio_Anterior_Valor',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.totalIngresosNetosAnuales.moneda':'Total_Ingresos_Netos_Anuales_Anio_Anterior_Moneda',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.fechaIngreso':'Fecha_Ingreso_Anio_Anterior',
       'declaracion.situacionPatrimonial.actividadAnualAnterior.fechaConclusion':'Fecha_Ingreso_Anio_Anterior',
       'estado':'Estado',
       'declaracion.situacionPatrimonial.datosEmpleoCargoComision.cuentaConOtroCargoPublico':'Cuenta_Con_Otro_Cargo_Publico',
       'declaracion.situacionPatrimonial.ingresos.remuneracionAnualCargoPublico.valor':'Ingresos_Remuneracion_Anual_Cargo_Publico_Valor',
       'declaracion.situacionPatrimonial.ingresos.remuneracionAnualCargoPublico.moneda':'Ingresos_Remuneracion_Anual_Cargo_Publico_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosAnualesTotal.valor':'Otros_Ingresos_Anuales_Total_Moneda',
       'declaracion.situacionPatrimonial.ingresos.otrosIngresosAnualesTotal.moneda':'Otros_Ingresos_Anuales_Total_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoAnualNetoDeclarante.valor':'Ingreso_Anual_Neto_Declarante_Valor',
       'declaracion.situacionPatrimonial.ingresos.ingresoAnualNetoDeclarante.moneda':'Ingreso_Anual_Neto_Declarante_Moneda',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosAnualesNetos.valor':'Total_Ingresos_Anuales_Netos_Valor',
       'declaracion.situacionPatrimonial.ingresos.totalIngresosAnualesNetos.moneda':'Total_Ingresos_Anuales_Netos_Moneda',
       'servidorPublicoSancionado.nombreCompleto':'Nombre_Completo'}, axis=1)
# Out:
#                            id   Fecha_actualizacion  \
# 0    6253a26f201c78ff11e318ab  2021-05-03T15:40:00Z
# 1    6253a26f201c78ff11e318b0  2021-05-03T15:42:34Z
# 2    6253a270201c78ff11e318b5  2021-05-03T15:44:25Z
# 3    6253a270201c78ff11e318b8  2021-05-03T15:45:59Z
# 4    6253a270201c78ff11e318bd  2021-05-03T15:49:32Z
# ..                        ...                   ...
# 176  63818f3f1e5398f68d0a666c  2022-11-24T18:20:45Z
# 177  6380410b1e5398f68d092b2d  2022-11-24T20:46:47Z
# 178  6381422c1e5398f68d0a1947  2022-11-25T03:11:27Z
# 179  6382a1001e5398f68d0b4da4  2022-11-26T12:11:38Z
# 180  6384db231e5398f68d0d4411  2022-11-28T01:24:52Z
#
#                                            Institucion  \
# 0            Universidad Autonoma del Estado de Mexico
# 1            Universidad Autonoma del Estado de Mexico
# 2            Universidad Autonoma del Estado de Mexico
# 3            Universidad Autonoma del Estado de Mexico
# 4            Universidad Autonoma del Estado de Mexico
# ...

# %% [markdown]
# # CSV

# %%
chiapas_s1.to_csv('/content/drive/MyDrive/Dataton_2022/data/S1_csv/chiapas_s1.csv', encoding='utf-8', index=False)

# %%
edomex_s1.to_csv('/content/drive/MyDrive/Dataton_2022/data/S1_csv/edomex_s1.csv', encoding='utf-8', index=False)

# %%
chiapas_s1.shape, edomex_s1.shape
# Out:
# ((33743, 78), (56181, 78))
