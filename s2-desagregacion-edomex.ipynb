# %%
import pandas as pd
import re

# %%
df = pd.read_csv('s2_edomex_v2.csv')

# %%
df['nivelResponsabilidad'] = df['nivelResponsabilidad'].astype(str)

# %%
my_list=df['nivelResponsabilidad'].tolist()

# %%
my_list2=df['tipoProcedimiento'].tolist()

# %%
responsabilidad = ['ATENCION', 'TRAMITACION', 'RESOLUCION', 'OTRO']

# %%
procedimiento = ['1', '2', '3', '4', '5']
procedimiento_dict = {
    '1' : 'CONTRATACIONES PUBLICAS',
    '2' : 'CONSECIONES LICENCIAS PERMISO AUTORIZACIONES PRORROGAS',
    '3' : 'ENAGENACION BIENES',
    '4' : 'DICTAMEN Y AVALUO',
    '5' : 'OTRO',
}

# %%
responsabilidad_to_add = []
for e in my_list:
    valores = []
    for w in responsabilidad:
        start_index = []
        start_index.append([i.start() for i in re.finditer(w, e)])
        if start_index[0]!= []:
            valores.append(w)
    responsabilidad_to_add.append(valores)

# %%
df['responsabilidades'] = responsabilidad_to_add

# %%
procedimiento_to_add = []
for e in my_list2:
    valores = []
    for n in procedimiento:
        start_index = []
        start_index.append([i.start() for i in re.finditer(n, e)])
        if start_index[0]!= []:
            valores.append(procedimiento_dict[n])
    procedimiento_to_add.append(valores)

# %%
df['procedimiento'] = procedimiento_to_add

# %%
df.head(10)
# Out:
#            fechaCaptura                               nivelResponsabilidad  \
# 0  2021-08-24T13:16:12Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 1  2021-08-24T13:17:32Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 2  2021-08-24T13:19:28Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 3  2021-08-24T13:21:01Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 4  2021-08-24T13:23:08Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 5  2021-08-24T13:23:39Z  [{'clave': 'A', 'valor': 'ATENCION'}, {'clave'...
# 6  2021-08-24T13:25:59Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 7  2021-08-24T13:28:05Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 8  2021-08-24T13:28:58Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
# 9  2021-08-24T13:29:26Z           [{'clave': 'T', 'valor': 'TRAMITACION'}]
#
#                                    tipoProcedimiento  \
# 0  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 1  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 2  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 4  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 5  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 6  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 7  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 8  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 9  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
#
#   institucionDependencia.nombre                          puesto.nombre  \
# 0                     Ocoyoacac                       DIRECTOR GENERAL
# 1                     Ocoyoacac                  SECRETARIO PARTICULAR
# 2                     Ocoyoacac                  SECRETARIO PARTICULAR
# 3                     Ocoyoacac                            SUBDIRECTOR
# 4                     Ocoyoacac                                REGIDOR
# 5                     Ocoyoacac                               DEFENSOR
# 6                     Ocoyoacac                                REGIDOR
# 7                     Ocoyoacac                                REGIDOR
# 8                     Ocoyoacac  Coordinadora,or de Eventos Especiales
# 9                     Ocoyoacac                           Defensora,or
#
#                            nombreCompleto        responsabilidades  \
# 0  GUILLERMO JUAN DE DIOS SANCHEZ AGUIRRE            [TRAMITACION]
# 1                      DANIELA REYES DIAZ            [TRAMITACION]
# 2                     DANIELA  REYES DIAZ            [TRAMITACION]
# 3                     MAGALY DIAZ SANTANA            [TRAMITACION]
# 4                       SILVIA REYES DIAZ            [TRAMITACION]
# 5                    GERARDO  REYES DIAZ   [ATENCION, TRAMITACION]
# 6                  ARTURO RODRIGUEZ REYES            [TRAMITACION]
# 7                     SILVIA  REYES  DIAZ            [TRAMITACION]
# 8                  ANDREA OLIVEROS MONTES            [TRAMITACION]
# 9                    JAVIER SIERRA ACOSTA            [TRAMITACION]
#
#                                    procedimiento
# 0  [CONTRATACIONES PUBLICAS, ENAGENACION BIENES]
# 1                      [CONTRATACIONES PUBLICAS]
# 2                      [CONTRATACIONES PUBLICAS]
# 3  [CONTRATACIONES PUBLICAS, ENAGENACION BIENES]
# 4                      [CONTRATACIONES PUBLICAS]
# 5                [CONTRATACIONES PUBLICAS, OTRO]
# 6                      [CONTRATACIONES PUBLICAS]
# 7                      [CONTRATACIONES PUBLICAS]
# 8                      [CONTRATACIONES PUBLICAS]
# 9                      [CONTRATACIONES PUBLICAS]

# %%
df.tail(10)
# Out:
#               fechaCaptura                               nivelResponsabilidad  \
# 3409  2021-02-26T13:30:19Z  [{'clave': 'A', 'valor': 'Atencion'}, {'clave'...
# 3410  2021-02-26T13:46:47Z  [{'clave': 'A', 'valor': 'Atencion'}, {'clave'...
# 3411  2021-02-26T14:00:24Z  [{'clave': 'A', 'valor': 'Atencion'}, {'clave'...
# 3412  2021-02-26T14:15:02Z  [{'clave': 'A', 'valor': 'Atencion'}, {'clave'...
# 3413  2021-02-26T16:59:09Z           [{'clave': 'T', 'valor': 'Tramitacion'}]
# 3414  2021-02-26T17:03:56Z           [{'clave': 'T', 'valor': 'Tramitacion'}]
# 3415  2021-02-26T17:08:28Z           [{'clave': 'T', 'valor': 'Tramitacion'}]
# 3416  2021-02-26T17:13:21Z  [{'clave': 'A', 'valor': 'Atencion'}, {'clave'...
# 3417  2021-02-26T17:20:51Z           [{'clave': 'T', 'valor': 'Tramitacion'}]
# 3418  2021-02-26T17:23:47Z           [{'clave': 'T', 'valor': 'Tramitacion'}]
#
#                                       tipoProcedimiento  \
# 3409                    [{'clave': 5, 'valor': 'OTRO'}]
# 3410  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3411  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3412  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3413  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3414  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3415  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3416  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3417  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
# 3418  [{'clave': 1, 'valor': 'CONTRATACIONES PUBLICA...
#
#      institucionDependencia.nombre                     puesto.nombre  \
# 3409                      Tultepec                          DIRECTOR
# 3410                      Tultepec                          DIRECTOR
# 3411                      Tultepec                         CONTRALOR
# 3412                      Tultepec                SECRETARIO TECNICO
# 3413                       Tecamac                          DIRECTOR
# 3414                       Tecamac              JEFE DE DEPARTAMENTO
# 3415                       Tecamac              JEFE DE DEPARTAMENTO
# 3416                       Tecamac                        DIRECTOR A
# 3417                       Tecamac                  DIRECTOR GENERAL
# 3418                       Tecamac  Coordinadora,or Administrativa,o
#
#                     nombreCompleto responsabilidades  \
# 3409        OSCAR  RAMIREZ PERALTA                []
# 3410       ARMANDO CERVANTES PUNZO                []
# 3411       JUAN ARMANDO LUNA AVILA                []
# 3412      DELFINO  SANDOVAL NOGUEZ                []
# 3413        OLGA  MOLINA HERNANDEZ                []
# 3414    JAIR EFRAIN ENCISO RAMIREZ                []
# 3415           JAIME ESTEVA OROZCO                []
# 3416  YOANA VANESSA  OROZCO SUAREZ                []
# 3417         ALONDRA  PARRA FLORES                []
# 3418        VERONICA ITURBE HUERTA                []
#
#                                           procedimiento
# 3409                                             [OTRO]
# 3410                    [CONTRATACIONES PUBLICAS, OTRO]
# 3411  [CONTRATACIONES PUBLICAS, ENAGENACION BIENES, ...
# 3412                    [CONTRATACIONES PUBLICAS, OTRO]
# 3413                    [CONTRATACIONES PUBLICAS, OTRO]
# 3414                    [CONTRATACIONES PUBLICAS, OTRO]
# 3415                    [CONTRATACIONES PUBLICAS, OTRO]
# 3416                    [CONTRATACIONES PUBLICAS, OTRO]
# 3417                    [CONTRATACIONES PUBLICAS, OTRO]
# 3418                    [CONTRATACIONES PUBLICAS, OTRO]

# %%
df.drop(['nivelResponsabilidad', 'tipoProcedimiento'], axis=1, inplace=True, errors='raise')

# %%
df.to_csv('s2_edomex_desagregado.csv')
